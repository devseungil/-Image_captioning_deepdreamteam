# %% [markdown]
# <a href="https://colab.research.google.com/github/MLP-deepdreamteam/Image_captioning_deepdreamteam/blob/branch_%ED%99%A9%EC%9D%B8/COCOImage30k_DB_table_EDA_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model, load_model

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#  gs://coco_custom30k/custom30k.zip

# %%
from zipfile import ZipFile

# %%
# !wget http://images.cocodataset.org/zips/train2017.zip -O coco_train2017.zip # 전체롤드

# %%
! gsutil cp gs://coco_custom30k/custom30k.zip /content/coco_custom30k
# Out:
# Copying gs://coco_custom30k/custom30k.zip...
# ==> NOTE: You are downloading one or more large file(s), which would
# run significantly faster if you enabled sliced object downloads. This
# feature is enabled by default but requires that compiled crcmod be
# installed (see "gsutil help crcmod").
#
# / [1 files][  4.6 GiB/  4.6 GiB]  122.2 MiB/s
# Operation completed over 1 objects/4.6 GiB.

# %%
with ZipFile("/content/coco_custom30k") as zfile:
  zfile.extractall(".")

# %%
# with GFile("gs://coco_custom30k/custom30k.zipl", "rb") as f:
#     dataset = pickle.load(f)

# %%
import pandas as pd
import json
# i = 0
# with open(f'/content/drive/MyDrive/coco_ann2017/annotations/captions_train2017.json', 'r') as f: # 마운트 확인
with open(f'/content/drive/MyDrive/coco_dataset/coco_ann2017/annotations/captions_train2017.json', 'r') as f: # 마운트 확인

    data = json.load(f)
    data = data['annotations']

img_cap_pairs = []

for sample in data:
    img_name = '%012d.jpg' % sample['image_id']
    img_cap_pairs.append([img_name, sample['caption'],sample['image_id']])

captions = pd.DataFrame(img_cap_pairs, columns=['image', 'caption','image_id'])
captions['image'] = captions['image'].apply(
    lambda x: f'/content/drive/MyDrive/coco_dataset//train2017/{x}'
)
captions = captions.reset_index(drop=True)
print(captions.head())
# Out:
#                                                image  \
# 0  /content/drive/MyDrive/coco_dataset//train2017...
# 1  /content/drive/MyDrive/coco_dataset//train2017...
# 2  /content/drive/MyDrive/coco_dataset//train2017...
# 3  /content/drive/MyDrive/coco_dataset//train2017...
# 4  /content/drive/MyDrive/coco_dataset//train2017...
#
#                                              caption  image_id
# 0  A bicycle replica with a clock as the front wh...    203564
# 1  A room with blue walls and a white sink and door.    322141
# 2  A car that seems to be parked illegally behind...     16977
# 3  A large passenger airplane flying through the ...    106140
# 4  There is a GOL plane taking off in a partly cl...    106140

# %%
df_captions_in_COCO = captions.groupby(["image", "image_id"])['caption'].apply(list).reset_index()


df_captions_in_COCO.shape


# # display(df_captions_in_COCO)

## sample 30k 생성용 
# # caption 길이가 5 이상이면 drop
# df_captions_in_COCO = df_captions_in_COCO[df_captions_in_COCO['caption'].apply(len) < 6]

# sample_30k  = df_captions_in_COCO.sample(30_000)
# Out:
# (118287, 3)

# %%
# df to dict


mypath_dict = {row['image']: row['caption'] for _, row in df_captions_in_COCO.iterrows()}

# Or, use the 'image_id' column as the key
myid_dict = {row['image_id']: row['caption'] for _, row in df_captions_in_COCO.iterrows()}

# %%
import os
sample_path ="/content/content/custom_train_coco_30k"
sample_train = os.listdir(sample_path)

# print(sample_train[:3])

# %%
my_sample_path = []
my_image_id= []

for jpg_file in sample_train:
    my_sample_path.append(sample_path+"/" +jpg_file)


    # exctract id in sample
    image_id = int(jpg_file.split('.')[0])
    my_image_id.append(image_id)

print(my_sample_path[:2],"\n", len(my_sample_path))
print()
print(my_image_id[:3], len(my_image_id))
# Out:
# ['/content/content/custom_train_coco_30k/000000460962.jpg', '/content/content/custom_train_coco_30k/000000009113.jpg']
#  30000
#
# [460962, 9113, 227550] 30000

# %%
# Function to check if the image ID is in the my_image_id list
def keep_id(image_id):
    return image_id in my_image_id

# Create a custom dictionary with only the partial image IDs
my_custom_train_set = {k: v for k, v in myid_dict.items() if keep_id(k)}

# %%
updated_dict = {}
for k, v in my_custom_train_set.items():
    
    new_key = sample_path+"/{:012d}.jpg".format(k)
    updated_dict[new_key] = v

# %%
len(updated_dict)
# Out:
# 30000

# %%
# 샘플 확인용

imgIdss= list(updated_dict.keys())
import random
random.shuffle(imgIdss)

# %%
import matplotlib.pyplot as plt
import skimage.io as io

# 랜덤 파일 읽기, imgidss 확인!! -전체코코인지 일부인지
fig = plt.gcf()
fig.set_size_inches(16, 16)

next_pix = imgIdss
random.shuffle(next_pix)

for i, img_path in enumerate(next_pix[0:12]):
    
    sp = plt.subplot(4, 4, i + 1)
    sp.axis('Off')
    I = io.imread(img_path)
    plt.imshow(I)
    print( updated_dict[img_path][0])

plt.show()
# Out:
# A laptop and different computer devices and a keyboard sitting on a desk.
# A person holds a bunch of under ripe bananas
# A giant donut, eclair, and cupcake represent some of the products made and sold by the company headquartered here.
# a close up of a dog laying on its back
# An orange cat sitting on top of a mouse.
# A couple of men playing tennis against each other.
# This is a street sign for NW Flanders St.
# A baby that is holding a banana in his mouth.
# A picture of a barbeque sandwich with lettuce on a bun.
# A woman walking across a beach holding a surfboard.
# Black and white photograph of a boy looking at a cellphone.
# A  small black sheep in a field with other larger sheep

# %%
dataset =updated_dict


list(dataset.keys())[:10]
#여기까지!
# Out:
# ['/content/content/custom_train_coco_30k/000000000025.jpg',
#  '/content/content/custom_train_coco_30k/000000000081.jpg',
#  '/content/content/custom_train_coco_30k/000000000089.jpg',
#  '/content/content/custom_train_coco_30k/000000000092.jpg',
#  '/content/content/custom_train_coco_30k/000000000151.jpg',
#  '/content/content/custom_train_coco_30k/000000000154.jpg',
#  '/content/content/custom_train_coco_30k/000000000165.jpg',
#  '/content/content/custom_train_coco_30k/000000000208.jpg',
#  '/content/content/custom_train_coco_30k/000000000250.jpg',
#  '/content/content/custom_train_coco_30k/000000000294.jpg']

# %%
df = pd.DataFrame.from_dict(dataset, orient='index')
display(df)
# Out:
#                                                                                                     0  \
# /content/content/custom_train_coco_30k/00000000...    A giraffe eating food from the top of the tree.
# /content/content/custom_train_coco_30k/00000000...          A big airplane flying in the big blue sky
# /content/content/custom_train_coco_30k/00000000...    An oven with a stove on top of it in a kitchen.
# /content/content/custom_train_coco_30k/00000000...   A white plate with a brownie and white frosting.
# /content/content/custom_train_coco_30k/00000000...  A stop sign directs pedestrians as a train tra...
# ...                                                                                               ...
# /content/content/custom_train_coco_30k/00000058...  A group of people standing next to each other ...
# /content/content/custom_train_coco_30k/00000058...  A large breed dog with black and brown fur is ...
# /content/content/custom_train_coco_30k/00000058...   A crowd of people flying kites on a sandy beach.
# /content/content/custom_train_coco_30k/00000058...  Four donuts in a box with a variety of frostings.
# /content/content/custom_train_coco_30k/00000058...  THERE IS A MAN THAT IS JUMPING HIGH ON A SNOW ...
#
#                                                                                                     1  \
# /content/content/custom_train_coco_30k/00000000...               A giraffe standing up nearby a tree
# /content/content/custom_train_coco_30k/00000000...  Large, two decked, four engined airliner in fl...
# /content/content/custom_train_coco_30k/00000000...        A stove with a lighted hood in the kitchen.
# /content/content/custom_train_coco_30k/00000000...  A piece of chocolate cake on top of a white pl...
# /content/content/custom_train_coco_30k/00000000...     A stop sign sits in the middle of the forest.
# ...                                                                                               ...
# /content/content/custom_train_coco_30k/00000058...  An old photograph of three women in front of net.
# /content/content/custom_train_coco_30k/00000058...  A brown dog standing on a white and black tile...
# /content/content/custom_train_coco_30k/00000058...        A group of people flying kites on the beach
# /content/content/custom_train_coco_30k/00000058...    a close up of many different kinds of doughnuts
# /content/content/custom_train_coco_30k/00000058...  A snowboarder is in the air as he attempts a s...
#
#                                                                                                     2  \
# /content/content/custom_train_coco_30k/00000000...      A giraffe mother with its baby in the forest.
# /content/content/custom_train_coco_30k/00000000...       An AirFrance jet airplane flying in the sky
# /content/content/custom_train_coco_30k/00000000...  A small light is on above the polished stove top.
# /content/content/custom_train_coco_30k/00000000...        a chocolate cake and a fork ready to be eat
# /content/content/custom_train_coco_30k/00000000...          A stop sign sitting near some tall trees.
# ...                                                                                               ...
# /content/content/custom_train_coco_30k/00000058...   Vintage photo of three women and a tennis court.
# /content/content/custom_train_coco_30k/00000058...  The dog is standing on a black and white check...
# /content/content/custom_train_coco_30k/00000058...    Many colorful kites are flying high in the air.
# /content/content/custom_train_coco_30k/00000058...                A group of donuts sitting in a box.
# /content/content/custom_train_coco_30k/00000058...     SNOW BOARDER JUMPING INTO THE AIR ON RED BOARD
#
#                                                                                                     3  \
# /content/content/custom_train_coco_30k/00000000...       Two giraffes standing in a tree filled area.
# /content/content/custom_train_coco_30k/00000000...      A big plane with AirFrance on the side of it.
# /content/content/custom_train_coco_30k/00000000...  Smooth top stove with exhaust fan that has lig...
# /content/content/custom_train_coco_30k/00000000...        A chocolate desert on a plate with a fork.
# /content/content/custom_train_coco_30k/00000000...  A man leans out of a vehicle near a short stop...
# ...                                                                                               ...
# /content/content/custom_train_coco_30k/00000058...  Three girls pose in front of a tennis net in a...
# /content/content/custom_train_coco_30k/00000058...  a dog that is standing on a black and white floor
# /content/content/custom_train_coco_30k/00000058...  A beach with various kites being flown while p...
# /content/content/custom_train_coco_30k/00000058...               an image of a box of donuts in a box
# /content/content/custom_train_coco_30k/00000058...  A snowboarder jumping high on a snowy day on t...
#
#                                                                                                     4
# /content/content/custom_train_coco_30k/00000000...  A giraffe standing next to a forest filled wit...
# /content/content/custom_train_coco_30k/00000000...             An Air France air plane in mid flight.
# /content/content/custom_train_coco_30k/00000000...  A stove top is cleaned with a set of knives on...
# /content/content/custom_train_coco_30k/00000000...  A piece of chocolate dessert on a plate with a...
# /content/content/custom_train_coco_30k/00000000...          A stop sign is shown close to the ground.
# ...                                                                                               ...
# /content/content/custom_train_coco_30k/00000058...  Three women who are posing together on a tenni...
# /content/content/custom_train_coco_30k/00000058...  There is a huge brown and black dog standing a...
# /content/content/custom_train_coco_30k/00000058...     Crowds of people flying kites over the desert.
# /content/content/custom_train_coco_30k/00000058...  A group of different types of doughnuts in a box.
# /content/content/custom_train_coco_30k/00000058...  A man riding an orange snow board jumping off ...
#
# [30000 rows x 5 columns]

# %%
df.columns = ['caption_1','caption_2','caption_3','caption_4','caption_5']
print(df.columns)
# Out:
# Index(['caption_1', 'caption_2', 'caption_3', 'caption_4', 'caption_5'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30000 entries, /content/content/custom_train_coco_30k/000000000025.jpg to /content/content/custom_train_coco_30k/000000581921.jpg
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   caption_1  30000 non-null  object
#  1   caption_2  30000 non-null  object
#  2   caption_3  30000 non-null  object
#  3   caption_4  30000 non-null  object
#  4   caption_5  30000 non-null  object
# dtypes: object(5)
# memory usage: 1.4+ MB

# %%
df=df.reset_index()

# %%
df
# Out:
#                                                    index  \
# 0      /content/content/custom_train_coco_30k/0000000...
# 1      /content/content/custom_train_coco_30k/0000000...
# 2      /content/content/custom_train_coco_30k/0000000...
# 3      /content/content/custom_train_coco_30k/0000000...
# 4      /content/content/custom_train_coco_30k/0000000...
# ...                                                  ...
# 29995  /content/content/custom_train_coco_30k/0000005...
# 29996  /content/content/custom_train_coco_30k/0000005...
# 29997  /content/content/custom_train_coco_30k/0000005...
# 29998  /content/content/custom_train_coco_30k/0000005...
# 29999  /content/content/custom_train_coco_30k/0000005...
#
#                                                caption_1  \
# 0        A giraffe eating food from the top of the tree.
# 1              A big airplane flying in the big blue sky
# 2        An oven with a stove on top of it in a kitchen.
# 3       A white plate with a brownie and white frosting.
# 4      A stop sign directs pedestrians as a train tra...
# ...                                                  ...
# 29995  A group of people standing next to each other ...
# 29996  A large breed dog with black and brown fur is ...
# 29997   A crowd of people flying kites on a sandy beach.
# 29998  Four donuts in a box with a variety of frostings.
# 29999  THERE IS A MAN THAT IS JUMPING HIGH ON A SNOW ...
#
#                                                caption_2  \
# 0                   A giraffe standing up nearby a tree
# 1      Large, two decked, four engined airliner in fl...
# 2            A stove with a lighted hood in the kitchen.
# 3      A piece of chocolate cake on top of a white pl...
# 4         A stop sign sits in the middle of the forest.
# ...                                                  ...
# 29995  An old photograph of three women in front of net.
# 29996  A brown dog standing on a white and black tile...
# 29997        A group of people flying kites on the beach
# 29998    a close up of many different kinds of doughnuts
# 29999  A snowboarder is in the air as he attempts a s...
#
#                                                caption_3  \
# 0          A giraffe mother with its baby in the forest.
# 1           An AirFrance jet airplane flying in the sky
# 2      A small light is on above the polished stove top.
# 3            a chocolate cake and a fork ready to be eat
# 4              A stop sign sitting near some tall trees.
# ...                                                  ...
# 29995   Vintage photo of three women and a tennis court.
# 29996  The dog is standing on a black and white check...
# 29997    Many colorful kites are flying high in the air.
# 29998                A group of donuts sitting in a box.
# 29999     SNOW BOARDER JUMPING INTO THE AIR ON RED BOARD
#
#                                                caption_4  \
# 0           Two giraffes standing in a tree filled area.
# 1          A big plane with AirFrance on the side of it.
# 2      Smooth top stove with exhaust fan that has lig...
# 3            A chocolate desert on a plate with a fork.
# 4      A man leans out of a vehicle near a short stop...
# ...                                                  ...
# 29995  Three girls pose in front of a tennis net in a...
# 29996  a dog that is standing on a black and white floor
# 29997  A beach with various kites being flown while p...
# 29998               an image of a box of donuts in a box
# 29999  A snowboarder jumping high on a snowy day on t...
#
#                                                caption_5
# 0      A giraffe standing next to a forest filled wit...
# 1                 An Air France air plane in mid flight.
# 2      A stove top is cleaned with a set of knives on...
# 3      A piece of chocolate dessert on a plate with a...
# 4              A stop sign is shown close to the ground.
# ...                                                  ...
# 29995  Three women who are posing together on a tenni...
# 29996  There is a huge brown and black dog standing a...
# 29997     Crowds of people flying kites over the desert.
# 29998  A group of different types of doughnuts in a box.
# 29999  A man riding an orange snow board jumping off ...
#
# [30000 rows x 6 columns]

# %%
 df.rename(columns={'index':'Img_address'}, inplace=True)
 df.head(5)
# Out:
#                                          Img_address  \
# 0  /content/content/custom_train_coco_30k/0000000...
# 1  /content/content/custom_train_coco_30k/0000000...
# 2  /content/content/custom_train_coco_30k/0000000...
# 3  /content/content/custom_train_coco_30k/0000000...
# 4  /content/content/custom_train_coco_30k/0000000...
#
#                                            caption_1  \
# 0    A giraffe eating food from the top of the tree.
# 1          A big airplane flying in the big blue sky
# 2    An oven with a stove on top of it in a kitchen.
# 3   A white plate with a brownie and white frosting.
# 4  A stop sign directs pedestrians as a train tra...
#
#                                            caption_2  \
# 0               A giraffe standing up nearby a tree
# 1  Large, two decked, four engined airliner in fl...
# 2        A stove with a lighted hood in the kitchen.
# 3  A piece of chocolate cake on top of a white pl...
# 4     A stop sign sits in the middle of the forest.
#
#                                            caption_3  \
# 0      A giraffe mother with its baby in the forest.
# 1       An AirFrance jet airplane flying in the sky
# 2  A small light is on above the polished stove top.
# 3        a chocolate cake and a fork ready to be eat
# 4          A stop sign sitting near some tall trees.
#
#                                            caption_4  \
# 0       Two giraffes standing in a tree filled area.
# 1      A big plane with AirFrance on the side of it.
# 2  Smooth top stove with exhaust fan that has lig...
# 3        A chocolate desert on a plate with a fork.
# 4  A man leans out of a vehicle near a short stop...
#
#                                            caption_5
# 0  A giraffe standing next to a forest filled wit...
# 1             An Air France air plane in mid flight.
# 2  A stove top is cleaned with a set of knives on...
# 3  A piece of chocolate dessert on a plate with a...
# 4          A stop sign is shown close to the ground.

# %%
df["Img_address"].apply(lambda x : x[-16:-4])
# Out:
# 0        000000000025
# 1        000000000081
# 2        000000000089
# 3        000000000092
# 4        000000000151
#              ...
# 29995    000000581839
# 29996    000000581873
# 29997    000000581884
# 29998    000000581913
# 29999    000000581921
# Name: Img_address, Length: 30000, dtype: object

# %%
df['id_key']=df["Img_address"].apply(lambda x : x[-16:-4])
df.head(5)
# Out:
#                                          Img_address  \
# 0  /content/content/custom_train_coco_30k/0000000...
# 1  /content/content/custom_train_coco_30k/0000000...
# 2  /content/content/custom_train_coco_30k/0000000...
# 3  /content/content/custom_train_coco_30k/0000000...
# 4  /content/content/custom_train_coco_30k/0000000...
#
#                                            caption_1  \
# 0    A giraffe eating food from the top of the tree.
# 1          A big airplane flying in the big blue sky
# 2    An oven with a stove on top of it in a kitchen.
# 3   A white plate with a brownie and white frosting.
# 4  A stop sign directs pedestrians as a train tra...
#
#                                            caption_2  \
# 0               A giraffe standing up nearby a tree
# 1  Large, two decked, four engined airliner in fl...
# 2        A stove with a lighted hood in the kitchen.
# 3  A piece of chocolate cake on top of a white pl...
# 4     A stop sign sits in the middle of the forest.
#
#                                            caption_3  \
# 0      A giraffe mother with its baby in the forest.
# 1       An AirFrance jet airplane flying in the sky
# 2  A small light is on above the polished stove top.
# 3        a chocolate cake and a fork ready to be eat
# 4          A stop sign sitting near some tall trees.
#
#                                            caption_4  \
# 0       Two giraffes standing in a tree filled area.
# 1      A big plane with AirFrance on the side of it.
# 2  Smooth top stove with exhaust fan that has lig...
# 3        A chocolate desert on a plate with a fork.
# 4  A man leans out of a vehicle near a short stop...
#
#                                            caption_5        id_key
# 0  A giraffe standing next to a forest filled wit...  000000000025
# 1             An Air France air plane in mid flight.  000000000081
# 2  A stove top is cleaned with a set of knives on...  000000000089
# 3  A piece of chocolate dessert on a plate with a...  000000000092
# 4          A stop sign is shown close to the ground.  000000000151

# %%
df.columns
# Out:
# Index(['Img_address', 'caption_1', 'caption_2', 'caption_3', 'caption_4',
#        'caption_5', 'id_key'],
#       dtype='object')

# %%
df = df[['id_key','Img_address', 'caption_1', 'caption_2', 'caption_3', 'caption_4',
       'caption_5']]

df.head(5)
# Out:
#          id_key                                        Img_address  \
# 0  000000000025  /content/content/custom_train_coco_30k/0000000...
# 1  000000000081  /content/content/custom_train_coco_30k/0000000...
# 2  000000000089  /content/content/custom_train_coco_30k/0000000...
# 3  000000000092  /content/content/custom_train_coco_30k/0000000...
# 4  000000000151  /content/content/custom_train_coco_30k/0000000...
#
#                                            caption_1  \
# 0    A giraffe eating food from the top of the tree.
# 1          A big airplane flying in the big blue sky
# 2    An oven with a stove on top of it in a kitchen.
# 3   A white plate with a brownie and white frosting.
# 4  A stop sign directs pedestrians as a train tra...
#
#                                            caption_2  \
# 0               A giraffe standing up nearby a tree
# 1  Large, two decked, four engined airliner in fl...
# 2        A stove with a lighted hood in the kitchen.
# 3  A piece of chocolate cake on top of a white pl...
# 4     A stop sign sits in the middle of the forest.
#
#                                            caption_3  \
# 0      A giraffe mother with its baby in the forest.
# 1       An AirFrance jet airplane flying in the sky
# 2  A small light is on above the polished stove top.
# 3        a chocolate cake and a fork ready to be eat
# 4          A stop sign sitting near some tall trees.
#
#                                            caption_4  \
# 0       Two giraffes standing in a tree filled area.
# 1      A big plane with AirFrance on the side of it.
# 2  Smooth top stove with exhaust fan that has lig...
# 3        A chocolate desert on a plate with a fork.
# 4  A man leans out of a vehicle near a short stop...
#
#                                            caption_5
# 0  A giraffe standing next to a forest filled wit...
# 1             An Air France air plane in mid flight.
# 2  A stove top is cleaned with a set of knives on...
# 3  A piece of chocolate dessert on a plate with a...
# 4          A stop sign is shown close to the ground.

# %%
df['caption_list'] = df['caption_1']+' '+df['caption_2']+' '+df['caption_3']+' '+df['caption_4']+' '+df['caption_5']
df.iloc[0,-1]
# Out:
# <ipython-input-40-83bf1a13c9cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['caption_list'] = df['caption_1']+' '+df['caption_2']+' '+df['caption_3']+' '+df['caption_4']+' '+df['caption_5']
# 'A giraffe eating food from the top of the tree. A giraffe standing up nearby a tree  A giraffe mother with its baby in the forest. Two giraffes standing in a tree filled area. A giraffe standing next to a forest filled with trees.'

# %%
df.head(5)
# Out:
#          id_key                                        Img_address  \
# 0  000000000025  /content/content/custom_train_coco_30k/0000000...
# 1  000000000081  /content/content/custom_train_coco_30k/0000000...
# 2  000000000089  /content/content/custom_train_coco_30k/0000000...
# 3  000000000092  /content/content/custom_train_coco_30k/0000000...
# 4  000000000151  /content/content/custom_train_coco_30k/0000000...
#
#                                            caption_1  \
# 0    A giraffe eating food from the top of the tree.
# 1          A big airplane flying in the big blue sky
# 2    An oven with a stove on top of it in a kitchen.
# 3   A white plate with a brownie and white frosting.
# 4  A stop sign directs pedestrians as a train tra...
#
#                                            caption_2  \
# 0               A giraffe standing up nearby a tree
# 1  Large, two decked, four engined airliner in fl...
# 2        A stove with a lighted hood in the kitchen.
# 3  A piece of chocolate cake on top of a white pl...
# 4     A stop sign sits in the middle of the forest.
#
#                                            caption_3  \
# 0      A giraffe mother with its baby in the forest.
# 1       An AirFrance jet airplane flying in the sky
# 2  A small light is on above the polished stove top.
# 3        a chocolate cake and a fork ready to be eat
# 4          A stop sign sitting near some tall trees.
#
#                                            caption_4  \
# 0       Two giraffes standing in a tree filled area.
# 1      A big plane with AirFrance on the side of it.
# 2  Smooth top stove with exhaust fan that has lig...
# 3        A chocolate desert on a plate with a fork.
# 4  A man leans out of a vehicle near a short stop...
#
#                                            caption_5  \
# 0  A giraffe standing next to a forest filled wit...
# 1             An Air France air plane in mid flight.
# 2  A stove top is cleaned with a set of knives on...
# 3  A piece of chocolate dessert on a plate with a...
# 4          A stop sign is shown close to the ground.
#
#                                         caption_list
# 0  A giraffe eating food from the top of the tree...
# 1  A big airplane flying in the big blue sky Larg...
# 2  An oven with a stove on top of it in a kitchen...
# 3  A white plate with a brownie and white frostin...
# 4  A stop sign directs pedestrians as a train tra...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_key        30000 non-null  object
#  1   Img_address   30000 non-null  object
#  2   caption_1     30000 non-null  object
#  3   caption_2     30000 non-null  object
#  4   caption_3     30000 non-null  object
#  5   caption_4     30000 non-null  object
#  6   caption_5     30000 non-null  object
#  7   caption_list  30000 non-null  object
# dtypes: object(8)
# memory usage: 1.8+ MB

# %%
#coco39k_img_db

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# %%
from sqlalchemy import text

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('/content/drive/MyDrive/3조/DB/coco30k.db')

# %%
df.to_sql('COCO30K_img', conn, if_exists='replace')
# Out:
# 30000

# %%
# with engine.connect() as conn:
  #  conn.execute(text("SELECT id_key FROM COCO30K_img")).fetchall()
pd.read_sql('select * FROM COCO30K_img',conn)
# Out:
#        index        id_key                                        Img_address  \
# 0          0  000000000025  /content/content/custom_train_coco_30k/0000000...
# 1          1  000000000081  /content/content/custom_train_coco_30k/0000000...
# 2          2  000000000089  /content/content/custom_train_coco_30k/0000000...
# 3          3  000000000092  /content/content/custom_train_coco_30k/0000000...
# 4          4  000000000151  /content/content/custom_train_coco_30k/0000000...
# ...      ...           ...                                                ...
# 29995  29995  000000581839  /content/content/custom_train_coco_30k/0000005...
# 29996  29996  000000581873  /content/content/custom_train_coco_30k/0000005...
# 29997  29997  000000581884  /content/content/custom_train_coco_30k/0000005...
# 29998  29998  000000581913  /content/content/custom_train_coco_30k/0000005...
# 29999  29999  000000581921  /content/content/custom_train_coco_30k/0000005...
#
#                                                caption_1  \
# 0        A giraffe eating food from the top of the tree.
# 1              A big airplane flying in the big blue sky
# 2        An oven with a stove on top of it in a kitchen.
# 3       A white plate with a brownie and white frosting.
# 4      A stop sign directs pedestrians as a train tra...
# ...                                                  ...
# 29995  A group of people standing next to each other ...
# 29996  A large breed dog with black and brown fur is ...
# 29997   A crowd of people flying kites on a sandy beach.
# 29998  Four donuts in a box with a variety of frostings.
# 29999  THERE IS A MAN THAT IS JUMPING HIGH ON A SNOW ...
#
#                                                caption_2  \
# 0                   A giraffe standing up nearby a tree
# 1      Large, two decked, four engined airliner in fl...
# 2            A stove with a lighted hood in the kitchen.
# 3      A piece of chocolate cake on top of a white pl...
# 4         A stop sign sits in the middle of the forest.
# ...                                                  ...
# 29995  An old photograph of three women in front of net.
# 29996  A brown dog standing on a white and black tile...
# 29997        A group of people flying kites on the beach
# 29998    a close up of many different kinds of doughnuts
# 29999  A snowboarder is in the air as he attempts a s...
#
#                                                caption_3  \
# 0          A giraffe mother with its baby in the forest.
# 1           An AirFrance jet airplane flying in the sky
# 2      A small light is on above the polished stove top.
# 3            a chocolate cake and a fork ready to be eat
# 4              A stop sign sitting near some tall trees.
# ...                                                  ...
# 29995   Vintage photo of three women and a tennis court.
# 29996  The dog is standing on a black and white check...
# 29997    Many colorful kites are flying high in the air.
# 29998                A group of donuts sitting in a box.
# 29999     SNOW BOARDER JUMPING INTO THE AIR ON RED BOARD
#
#                                                caption_4  \
# 0           Two giraffes standing in a tree filled area.
# 1          A big plane with AirFrance on the side of it.
# 2      Smooth top stove with exhaust fan that has lig...
# 3            A chocolate desert on a plate with a fork.
# 4      A man leans out of a vehicle near a short stop...
# ...                                                  ...
# 29995  Three girls pose in front of a tennis net in a...
# 29996  a dog that is standing on a black and white floor
# 29997  A beach with various kites being flown while p...
# 29998               an image of a box of donuts in a box
# 29999  A snowboarder jumping high on a snowy day on t...
#
#                                                caption_5  \
# 0      A giraffe standing next to a forest filled wit...
# 1                 An Air France air plane in mid flight.
# 2      A stove top is cleaned with a set of knives on...
# 3      A piece of chocolate dessert on a plate with a...
# 4              A stop sign is shown close to the ground.
# ...                                                  ...
# 29995  Three women who are posing together on a tenni...
# 29996  There is a huge brown and black dog standing a...
# 29997     Crowds of people flying kites over the desert.
# 29998  A group of different types of doughnuts in a box.
# 29999  A man riding an orange snow board jumping off ...
#
#                                             caption_list
# 0      A giraffe eating food from the top of the tree...
# 1      A big airplane flying in the big blue sky Larg...
# 2      An oven with a stove on top of it in a kitchen...
# 3      A white plate with a brownie and white frostin...
# 4      A stop sign directs pedestrians as a train tra...
# ...                                                  ...
# 29995  A group of people standing next to each other ...
# 29996  A large breed dog with black and brown fur is ...
# 29997  A crowd of people flying kites on a sandy beac...
# 29998  Four donuts in a box with a variety of frostin...
# 29999  THERE IS A MAN THAT IS JUMPING HIGH ON A SNOW ...
#
# [30000 rows x 9 columns]

# %%
import sqlite3
import pandas as pd

# SQLite3 데이터베이스 파일에 연결
conn = sqlite3.connect('coco30k.db')

# 이미 존재하는 DataFrame
df4 = pd.DataFrame({'id': ['123'], 'name': ['hi']})

# DataFrame을 SQLite3 데이터베이스로 보내기
df4.to_sql('test', conn, if_exists='replace')

# SQLite3 데이터베이스 파일 닫기
conn.close()

# %%
conn.close()

# %%
a=[]

# %%
df_custom_input = pd.DataFrame(a, columns=['id_key','image_file'])

# %%
df_custom_input
# Out:
# Empty DataFrame
# Columns: [id_key, image_file]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_key        30000 non-null  object
#  1   Img_address   30000 non-null  object
#  2   caption_1     30000 non-null  object
#  3   caption_2     30000 non-null  object
#  4   caption_3     30000 non-null  object
#  5   caption_4     30000 non-null  object
#  6   caption_5     30000 non-null  object
#  7   caption_list  30000 non-null  object
# dtypes: object(8)
# memory usage: 1.8+ MB

# %%
df.describe(include='all')
# Out:
#               id_key                                        Img_address  \
# count          30000                                              30000
# unique         30000                                              30000
# top     000000000025  /content/content/custom_train_coco_30k/0000000...
# freq               1                                                  1
#
#                                          caption_1  \
# count                                        30000
# unique                                       29437
# top     A man riding a wave on top of a surfboard.
# freq                                            20
#
#                                  caption_2  \
# count                                30000
# unique                               29796
# top     A person on some skis in the snow.
# freq                                     8
#
#                                         caption_3  \
# count                                       30000
# unique                                      29833
# top     A person on a court with a tennis racket.
# freq                                            6
#
#                                             caption_4  \
# count                                           30000
# unique                                          29820
# top     a person riding a skate board at a skate park
# freq                                                8
#
#                                   caption_5  \
# count                                 30000
# unique                                29821
# top     I am unable to see the image above.
# freq                                      5
#
#                                              caption_list
# count                                               30000
# unique                                              30000
# top     A giraffe eating food from the top of the tree...
# freq                                                    1

# %%
max_lengths = df.applymap(lambda x: len(str(x))).max()

# %%
print(max_lengths)
# Out:
# id_key           12
# Img_address      55
# caption_1       235
# caption_2       250
# caption_3       240
# caption_4       250
# caption_5       244
# caption_list    601
# dtype: int64

# %%
max_lengths = df.applymap(lambda x: len(str(x))).idxmax()

# %%
print(max_lengths)
# Out:
# id_key              0
# Img_address         0
# caption_1       26529
# caption_2       25202
# caption_3        4488
# caption_4       19899
# caption_5        5664
# caption_list     4445
# dtype: int64

# %%
df.iloc[26529,2]
# Out:
# 'Off in the distance, a few people dot the stands and the fenced in area bordering a ball field, while an umpire and three uniformed baseball players, including a batter, catcher and outfielder, strike playing poses in the foreground.  '

# %%
df.iloc[25202,4]
# Out:
# 'People are standing in a field under British flags.'

# %%
for i in range(1,6):
  df_cap_len = df[f'caption_{i}'].apply(len)>100
  print(df_cap_len.sum())
  df[f'caption_{i}'][df_cap_len]
# Out:
# 169
# 231
# 254
# 256
# 252

# %%
df_test=df
for i in range(1, 6):
    df_test = df_test[df_test[f'caption_{i}'].apply(len) <= 100]

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28871 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_key        28871 non-null  object
#  1   Img_address   28871 non-null  object
#  2   caption_1     28871 non-null  object
#  3   caption_2     28871 non-null  object
#  4   caption_3     28871 non-null  object
#  5   caption_4     28871 non-null  object
#  6   caption_5     28871 non-null  object
#  7   caption_list  28871 non-null  object
# dtypes: object(8)
# memory usage: 2.0+ MB

# %%
max_lengths = df_test.applymap(lambda x: len(str(x))).max()
max_lengths
# Out:
# id_key           12
# Img_address      55
# caption_1       100
# caption_2       100
# caption_3       100
# caption_4       100
# caption_5       100
# caption_list    434
# dtype: int64

# %%
df_test.describe()
# Out:
#               id_key                                        Img_address  \
# count          28871                                              28871
# unique         28871                                              28871
# top     000000000025  /content/content/custom_train_coco_30k/0000000...
# freq               1                                                  1
#
#                                          caption_1  \
# count                                        28871
# unique                                       28336
# top     A man riding a wave on top of a surfboard.
# freq                                            20
#
#                                                 caption_2  \
# count                                               28871
# unique                                              28673
# top     A man riding a snowboard down a snow covered s...
# freq                                                    8
#
#                                                 caption_3  \
# count                                               28871
# unique                                              28712
# top     A man holding a tennis racquet on a tennis court.
# freq                                                    6
#
#                                             caption_4  \
# count                                           28871
# unique                                          28700
# top     a person riding a skate board at a skate park
# freq                                                7
#
#                                          caption_5  \
# count                                        28871
# unique                                       28699
# top     A man riding a wave on top of a surfboard.
# freq                                             5
#
#                                              caption_list
# count                                               28871
# unique                                              28871
# top     A giraffe eating food from the top of the tree...
# freq                                                    1

# %%
df_test['caption_list']= df_test['caption_list'].apply(lambda x : x.lower())

# %%
df_test.describe()
# Out:
#               id_key                                        Img_address  \
# count          28871                                              28871
# unique         28871                                              28871
# top     000000000025  /content/content/custom_train_coco_30k/0000000...
# freq               1                                                  1
#
#                                          caption_1  \
# count                                        28871
# unique                                       28336
# top     A man riding a wave on top of a surfboard.
# freq                                            20
#
#                                                 caption_2  \
# count                                               28871
# unique                                              28673
# top     A man riding a snowboard down a snow covered s...
# freq                                                    8
#
#                                                 caption_3  \
# count                                               28871
# unique                                              28712
# top     A man holding a tennis racquet on a tennis court.
# freq                                                    6
#
#                                             caption_4  \
# count                                           28871
# unique                                          28700
# top     a person riding a skate board at a skate park
# freq                                                7
#
#                                          caption_5  \
# count                                        28871
# unique                                       28699
# top     A man riding a wave on top of a surfboard.
# freq                                             5
#
#                                              caption_list
# count                                               28871
# unique                                              28871
# top     a giraffe eating food from the top of the tree...
# freq                                                    1

# %%
df['caption_5'].str.contains('unable').sum()
# Out:
# 8

# %%
parse = df_test['caption_list'].str.contains('A man is sitting')

# df_test[parse
parse

# idx = df_test['caption_list'][parse].index


# df_test
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998    False
# 29999    False
# Name: caption_list, Length: 28871, dtype: bool

# %%
df_test['caption_list'][df_test['caption_list'].str.contains('a man is sitting')].iloc[8]
# Out:
# 'a black and white photo of a man on a bench a man sitting on a wooden bench by his self a man is sitting on a bench reading a newspaper. man with a bag sitting on a bench reading a magazine.  a man reading a paper on a bench.'

# %%
df_test['caption_5'][df_test['caption_5'].str.contains('unable')]
# Out:
# 2651       I am unable to see the image above.
# 3300       I am unable to see a picture above.
# 4765        I am unable to see an image above.
# 10373    I am unable to see any picture above.
# 12569      I am unable to see the image above.
# 14589      I am unable to see the image above.
# 19003      I am unable to see the image above.
# 22318      I am unable to see the image above.
# Name: caption_5, dtype: object

# %%
df_test_2 = df_test
for i in range(1, 6):
    df_test_2 = df_test_2[~df_test_2[f'caption_{i}'].str.contains('unable')]
    # ~df_test_2[f'caption_{i}'].str.contains('unable')

# %%
df_test_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28846 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_key        28846 non-null  object
#  1   Img_address   28846 non-null  object
#  2   caption_1     28846 non-null  object
#  3   caption_2     28846 non-null  object
#  4   caption_3     28846 non-null  object
#  5   caption_4     28846 non-null  object
#  6   caption_5     28846 non-null  object
#  7   caption_list  28846 non-null  object
# dtypes: object(8)
# memory usage: 2.0+ MB

# %%
max_lengths2 = df_test_2.applymap(lambda x: len(str(x))).max()
max_lengths2
# Out:
# id_key           12
# Img_address      55
# caption_1       100
# caption_2       100
# caption_3       100
# caption_4       100
# caption_5       100
# caption_list    434
# dtype: int64

# %%
df_test[caption_5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-5ff847e26082> in <cell line: 1>()
# ----> 1 df_test[caption_5]
#
# NameError: name 'caption_5' is not defined

# %%
print(len('/content/drive/Shareddrives/coco_dataset/destination_folder/train_folder01/000000048794.jpg'))

# %%
from itertools import chain
from tensorflow.keras.preprocessing.text import Tokenizer

# 30K 단어 토큰화 # 15k만들기는 아직 보류

def tokenize_mycaption(dataset, max_words=15000):
  
  flatten_list = list(chain.from_iterable(dataset.values())) #[[1,3],[4,8]] = [1,3,4,8]

  tokenizer = Tokenizer( oov_token='<oov>') # For those words which are not found in word_index
  tokenizer.fit_on_texts(flatten_list)
  total_words = len(tokenizer.word_index) + 1
  print("Vocabulary length: ", total_words)
  print(list(tokenizer.word_index.keys())[:10])
  return tokenizer, total_words

tokenizer, total_words = tokenize_mycaption(dataset, max_words=15000)

# %%
# dataset 에 <start>, <end> 넣기, LSTM 용

newdataset = {k: ['<start> '   +cap+ ' <end>' for cap in caps] for k,caps in dataset.items()}

print(len(newdataset))
print(list(newdataset.items())[0])
print(len(list(newdataset.values())[0]))

dataset =newdataset

# %%
import itertools


# 임시 : sample은 개수

SAMPLE_NUM=10
testsample_dict= dict(itertools.islice(dataset.items(), SAMPLE_NUM))


# sample 쓴다고 가정
# dataset = testsample_dict

# %%
# # 해당 3만개 데이터에 대한 tokenizer 저장  (15691 단어 수)

# import pickle

# # Save the configuration and weights to a file
# with open(f"my_tokenizer_{my_part}.pkl", "wb") as f:
#     pickle.dump({"tokenizer": tokenizer}, f)

# %%
# Image Augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_gen = ImageDataGenerator(
    # featurewise_center=False,
    # samplewise_center=False,
    # featurewise_std_normalization=False,
    # samplewise_std_normalization=False,
    # zca_whitening=False,
    # zca_epsilon=1e-06,
    # rotation_range=0,
    width_shift_range=0.1, # changed
    height_shift_range=0.1, # changed
    # brightness_range=None,
    shear_range=0.1, # changed
    zoom_range=0.1, # changed
    # channel_shift_range=0.0,
    # fill_mode='nearest',
    # cval=0.0,
    horizontal_flip=True, # changed
    vertical_flip=False,
    # rescale=None,
    # preprocessing_function=None,
    # data_format=None,
    # validation_split=0.0,
    # interpolation_order=1,
    # dtype=None
)

# %%
# Encoder 인 Xception 모델 호출, image_feature, imsize, error_imgs 선언, img_preprocess (이미지 사이즈 model 에 맞게 + resize, + 정규화 + feature 추출)


from tensorflow.keras.applications.xception import Xception
from tqdm.notebook import tqdm
import cv2
import numpy as np

model = Xception(include_top=False, pooling='avg',  weights='imagenet')

# model.compile()

image_features = {}

imsize = (299,299)
# dataset.keys()
error_imgs = []
# 윤성(230411/aug : True->False)
# def img_preprocess(dataset=dataset,imsize=imsize, model=model, aug =True  ):
def img_preprocess(dataset=dataset,imsize=imsize, model=model, aug =False  ):
    for img in tqdm(list(dataset.keys())):
        try:
            image = io.imread(img)
            if image.ndim != 3:
                image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

            # Resize each image size 299 x 299 or 224 X 224
            image = cv2.resize(image, (imsize[1], imsize[0]))
            image = np.expand_dims(image, axis=0)
            if aug == True:
              augmented_image = data_gen.flow(image, batch_size=1).next()
              image = augmented_image

            # Normalize image pixels
            image = image / 127.5
            image = image - 1.0

            # Extract features from image
            feature = model.predict(image)
            image_features[img] = feature

        except:
            print(f"Failed to process image {img}")
            error_imgs.append[img]

# %%
# MobileNet Feature extraction 용
from tensorflow.keras.layers import GlobalAveragePooling2D

IMAGE_SHAPE=(224, 224, 3)
mobilenet = tf.keras.applications.MobileNetV3Small(
    input_shape=IMAGE_SHAPE,
    include_top=False,
    include_preprocessing=True)
mobilenet.trainable=False

x = mobilenet.output
x = GlobalAveragePooling2D()(x)

modified_mobilenetv3small = Model(inputs=mobilenet.input, outputs=x)

# img_preprocess(dataset, imsize =IMAGE_SHAPE, model = modified_mobilenetv3small)

# %%
# 윤성추가(230411)
# model_incep.summary()
import tensorflow as tf
from tensorflow.keras.layers import GlobalAveragePooling2D

# %%
# from tensorflow.keras.layers import GlobalAveragePooling2D

IMAGE_SHAPE=(224, 224, 3)

vgg16 = tf.keras.applications.vgg16.VGG16(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation='softmax'
) 
vgg16.trainable=False

x = vgg16.output
x = GlobalAveragePooling2D()(x)

modified_vgg16 = Model(inputs=vgg16.input, outputs=x)

# %%
#윤성추가(230411)
# modified_vgg16.summary()

img_preprocess(dataset, imsize =IMAGE_SHAPE, model = modified_vgg16)
# 뒤에 각모델마다  호출할때 모델 피팅 따로적용해야함

# %%
print("Image features length: ", len(image_features))

# %%
# testsample_dict

# img_preprocess ( dataset = testsample_dict )

# %%
print(len(image_features))
print(list(image_features.items())[-1])

# %%
# 윤성 07,08,09
import pickle
# Get the tokenizer's configuration and weights
# image_features

# 각자 Sampletrain 별로 저장하기 
# ex) train

# 윤성(230411/aug : True->False)
# with open(f"my_feature_{len(image_features)}_{my_part}.pkl", "wb") as f:
# with open(f"vgg16_feature_{len(image_features)}_aug_True.pkl", "wb") as f:
# with open(f"vgg16_feature_{len(image_features)}_aug_False.pkl", "wb") as f:
#     pickle.dump({"feature": image_features}, f)
model_e = 'vgg_t'

# %%
if model_e=='vgg_t':
    print("loading :",model_e)
    with open("/content/drive/MyDrive/3조/features_VGG16_30K/vgg16_feature_30000_aug_True.pkl", "rb") as f:    
      load_feature_file = pickle.load(f)
# 윤성(230417 추가)
elif model_e=='vgg_f':
  print("loading :",model_e)
  with open("/content/drive/MyDrive/3조/features_VGG16_30K/vgg16_feature_30000_aug_False.pkl", "rb") as f:    
    load_feature_file = pickle.load(f)

elif model_e=='xception_t':
  print("loading :",model_e)
  with open("/content/drive/MyDrive/3조/features_Xception_30K/my_feature_30000_yes_aug.pkl", "rb") as f:    
    load_feature_file = pickle.load(f)
elif model_e=='xception_f':
  print("loading :",model_e)
  with open("/content/drive/MyDrive/3조/features_Xception_30K/my_feature_30000_no_aug.pkl", "rb") as f:    
    load_feature_file = pickle.load(f)

elif model_e=='mobilenet_t':
    print("loading :",model_e)
    with open("/content/drive/MyDrive/3조/features_Mobilenet_30K/my_feature_30000_mb_yes_aug.pkl", "rb") as f:    
      load_feature_file = pickle.load(f)

elif model_e=='mobilenet_f':
      print("loading :",model_e)
      with open("/content/drive/MyDrive/3조/features_Mobilenet_30K/my_feature_30000_mb_no_aug.pkl", "rb") as f:    
        load_feature_file = pickle.load(f)
else:
      pass
# Out:
# loading : vgg_t

# %%
import numpy as np

dfk = load_feature_file["feature"].keys()


dfv = load_feature_file["feature"].values()
keys =[k[-16:-3]for k in dfk]


df_features = pd.DataFrame({"id_key":keys, "vgg_true_feature_vector":dfv})

# %%
df_features.describe

df_features.head(2)
# Out:
#           id_key                            vgg_true_feature_vector
# 0  000000000025.  [[0.24897842, 0.0, 0.43897817, 0.04171432, 0.1...
# 1  000000000081.  [[0.20664741, 0.0, 0.11101636, 0.08395214, 0.2...

# %%
# df_features = df_features[['id_key']]

# %%
df_features.to_sql('extracted_feature_vgg_2', conn, if_exists='replace')

# %%
pd.read_sql('select * FROM COCO30K_img',conn)
